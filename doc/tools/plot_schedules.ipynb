# %%
import os
import sys

cwd = os.getcwd()
parent_dir = cwd + "/../.."
sys.path.insert(1, parent_dir)

print("Directory containing the notebook:")
print(cwd)
# Out:
# Directory containing the notebook:
# /home/users/jwakim/CodeDev/chromo_check_density_calculation/doc/tools

# %%
from inspect import getmembers, isfunction

import numpy as np
import matplotlib.pyplot as plt

import doc.tools.mu_schedules as ms

# %%
schedules = [func[0] for func in getmembers(ms, isfunction)]
print(schedules)
# Out:
# ['linear_1', 'linear_2', 'linear_2_for_negative_cp', 'linear_3', 'linear_4', 'linear_step_for_negative_cp', 'log_1', 'log_2', 'log_3', 'sawtooth_1', 'tanh_1', 'tanh_2', 'tanh_3', 'tanh_4']

# %%
N = 250
i = np.arange(0, N, 1)

for func_name in schedules:
    schedule = getattr(ms, func_name)
    y = [schedule(ind, N) for ind in i]

    plt.figure(figsize=(6, 3), dpi = 300)
    plt.plot(i, y)
    # plt.xlim(0, 200)
    # plt.ylim(-1.1, 1.1)
    plt.xlabel("Snapshot")
    plt.ylabel("Mu Adjustment Factor")
    plt.title(func_name.replace("_", " "))
    plt.show()

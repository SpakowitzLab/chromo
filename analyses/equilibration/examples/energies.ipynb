# %% [markdown]
# # Evaluate Energy Convergence
#
# The total system energy is comprised of polymer elastic energy and field-based interaction energies. In this notebook, we plot energy convergence over the course of a simulation.

# %% [markdown]
# ### Import Modules

# %%
# Third-party Modules
from IPython.display import Image, display

# Custom Modules
from analyses.equilibration.energies import plot_configurational_energies

# %% [markdown]
# ### Specify Simulation

# %%
output_dir = "/scratch/users/jwakim/chromo_two_mark_phase_transition/output"
sim_ind = 33
save_name = "energy_equilibration.png"

# %% [markdown]
# ### Compute Energy Profile

# %%
# %%capture
plot_configurational_energies(output_dir, sim_ind, save_name)

# %% [markdown]
# ### Load Energy Profile

# %%
save_path = f"{output_dir}/sim_{sim_ind}/{save_name}"
display(Image(filename=save_path))

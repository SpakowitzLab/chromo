# %% [markdown]
# # Plot Converge of Mean Squared End-to-End Distance (MSD)
#
# For a specified bead range, calculate the mean squared end-to-end distance for each snapshot.

# %% [markdown]
# ### Import Modules

# %%
# Third-party Modules
from IPython.display import Image, display

# Custom Modules
from analyses.equilibration.MSDs import plot_MSDs

# %% [markdown]
# ### Specify Simulation

# %%
output_dir = "/scratch/users/jwakim/chromo_two_mark_phase_transition/output"
sim_ind = 33
seg_length = 50
lp = 53
save_name = "MSD_equilibration.png"

# %% [markdown]
# ### Compute MSD Profile

# %%
plot_MSDs(output_dir, sim_ind, seg_length, lp, save_name)

# %% [markdown]
# ### Load MSD Profile

# %%
save_path = f"{output_dir}/sim_{sim_ind}/{save_name}"
display(Image(filename=save_path))

# %% [markdown]
# # Inspect Simulation Parameters
#
# Load simulation parameters from the output directory into a JSON file.

# %% [markdown]
# ### Import Modules

# %%
from pprint import pprint

from analyses.characterizations.inspect_simulations import (
    get_sim_paths, get_binder_params, match_two_mark_sims,
    convert_to_numeric, get_field_parameters, create_parameter_json
)

# %% [markdown]
# ### List Simulation Directories

# %%
output_dir = "/scratch/users/jwakim/chromo_two_mark_phase_transition/output/full_factorial_batch_2"
sim_names, sim_inds, sim_paths = get_sim_paths(output_dir)
print("Simulations: \n")
print(sim_names)
# Out:
# Simulations:
#
# ['sim_1', 'sim_2', 'sim_3', 'sim_4', 'sim_5', 'sim_6', 'sim_7', 'sim_8', 'sim_9', 'sim_10', 'sim_11', 'sim_12', 'sim_13', 'sim_14', 'sim_15', 'sim_16', 'sim_17', 'sim_18', 'sim_19', 'sim_20', 'sim_21', 'sim_22', 'sim_23', 'sim_24', 'sim_25', 'sim_26', 'sim_27', 'sim_28', 'sim_29', 'sim_30', 'sim_31', 'sim_32', 'sim_33', 'sim_34', 'sim_35', 'sim_36', 'sim_37', 'sim_38', 'sim_39', 'sim_40', 'sim_41', 'sim_42', 'sim_43', 'sim_44', 'sim_45', 'sim_46', 'sim_47', 'sim_48', 'sim_49', 'sim_50', 'sim_51', 'sim_52', 'sim_53', 'sim_54', 'sim_55', 'sim_56', 'sim_57', 'sim_58', 'sim_59', 'sim_60', 'sim_61', 'sim_62', 'sim_63', 'sim_64']

# %% [markdown]
# ### Load Binder Parameters

# %%
binder_params = get_binder_params(sim_names, sim_paths)
print("Binder Parameters: \n")
pprint(binder_params)
# Out:
# Binder Parameters:
#
# {'sim_1': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 1978379.047},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                    'field_energy_prefactor': -6594596.824,
#                    'interaction_energy': -5.0,
#                    'interaction_energy_intranucleosome': -4.976,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_10': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_11': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_12': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_13': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_14': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_15': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_16': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_17': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_18': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_19': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_2': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 1978379.047},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                    'field_energy_prefactor': -6594596.824,
#                    'interaction_energy': -5.0,
#                    'interaction_energy_intranucleosome': -4.976,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_20': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_21': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_22': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_23': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_24': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_25': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_26': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_27': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_28': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_29': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_3': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.5,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 1978379.047},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                    'field_energy_prefactor': -5935137.141,
#                    'interaction_energy': -4.5,
#                    'interaction_energy_intranucleosome': -4.478,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_30': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_31': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_32': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_33': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_34': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_35': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_36': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_37': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_38': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_39': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_4': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 659459.682},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                    'field_energy_prefactor': -6594596.824,
#                    'interaction_energy': -5.0,
#                    'interaction_energy_intranucleosome': -4.976,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_40': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_41': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
# ...
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_58': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_59': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_6': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 1978379.047},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                    'field_energy_prefactor': -5935137.141,
#                    'interaction_energy': -4.5,
#                    'interaction_energy_intranucleosome': -4.478,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_60': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.3,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_61': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 659459.682},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_62': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -6594596.824,
#                      'interaction_energy': -5.0,
#                      'interaction_energy_intranucleosome': -4.976,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_63': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_64': {'HP1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.5,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 1978379.047},
#                     'cross_talk_interaction_energy': "{'PRC1': 0.75}",
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2},
#             'PRC1': {'bind_energy_mod': -0.01,
#                      'bind_energy_no_mod': 1.52,
#                      'chemical_potential': -0.5,
#                      'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                            'PRC1': 0.0},
#                      'cross_talk_interaction_energy': '{}',
#                      'field_energy_prefactor': -5935137.141,
#                      'interaction_energy': -4.5,
#                      'interaction_energy_intranucleosome': -4.478,
#                      'interaction_radius': 3.0,
#                      'interaction_volume': 113.097,
#                      'sites_per_bead': 2}},
#  'sim_7': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 659459.682},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                    'field_energy_prefactor': -5935137.141,
#                    'interaction_energy': -4.5,
#                    'interaction_energy_intranucleosome': -4.478,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -5935137.141,
#                     'interaction_energy': -4.5,
#                     'interaction_energy_intranucleosome': -4.478,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_8': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 659459.682},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                    'field_energy_prefactor': -5935137.141,
#                    'interaction_energy': -4.5,
#                    'interaction_energy_intranucleosome': -4.478,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}},
#  'sim_9': {'HP1': {'bind_energy_mod': -0.01,
#                    'bind_energy_no_mod': 1.52,
#                    'chemical_potential': -0.3,
#                    'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                          'PRC1': 659459.682},
#                    'cross_talk_interaction_energy': "{'PRC1': 0.25}",
#                    'field_energy_prefactor': -6594596.824,
#                    'interaction_energy': -5.0,
#                    'interaction_energy_intranucleosome': -4.976,
#                    'interaction_radius': 3.0,
#                    'interaction_volume': 113.097,
#                    'sites_per_bead': 2},
#            'PRC1': {'bind_energy_mod': -0.01,
#                     'bind_energy_no_mod': 1.52,
#                     'chemical_potential': -0.3,
#                     'cross_talk_field_energy_prefactor': {'HP1': 0.0,
#                                                           'PRC1': 0.0},
#                     'cross_talk_interaction_energy': '{}',
#                     'field_energy_prefactor': -6594596.824,
#                     'interaction_energy': -5.0,
#                     'interaction_energy_intranucleosome': -4.976,
#                     'interaction_radius': 3.0,
#                     'interaction_volume': 113.097,
#                     'sites_per_bead': 2}}}

# %% [markdown]
# ### Pair Simulations
#
# Match simulations with matching binder parameters.

# %%
matching_sims = match_two_mark_sims(sim_names, binder_params)
print("Simulations Matched by Binder Parameters: \n")
pprint(matching_sims)
# Out:
# Simulations Matched by Binder Parameters:
#
# {'-0.3;-0.3;-4.5;-4.5;0.25': ['sim_7', 'sim_38'],
#  '-0.3;-0.3;-4.5;-4.5;0.75': ['sim_6', 'sim_48'],
#  '-0.3;-0.3;-4.5;-5.0;0.25': ['sim_8', 'sim_34'],
#  '-0.3;-0.3;-4.5;-5.0;0.75': ['sim_12', 'sim_40'],
#  '-0.3;-0.3;-5.0;-4.5;0.25': ['sim_13', 'sim_36'],
#  '-0.3;-0.3;-5.0;-4.5;0.75': ['sim_10', 'sim_43'],
#  '-0.3;-0.3;-5.0;-5.0;0.25': ['sim_9', 'sim_33'],
#  '-0.3;-0.3;-5.0;-5.0;0.75': ['sim_1', 'sim_35'],
#  '-0.3;-0.5;-4.5;-4.5;0.25': ['sim_16', 'sim_55'],
#  '-0.3;-0.5;-4.5;-4.5;0.75': ['sim_26', 'sim_63'],
#  '-0.3;-0.5;-4.5;-5.0;0.25': ['sim_21', 'sim_47'],
#  '-0.3;-0.5;-4.5;-5.0;0.75': ['sim_14', 'sim_58'],
#  '-0.3;-0.5;-5.0;-4.5;0.25': ['sim_24', 'sim_53'],
#  '-0.3;-0.5;-5.0;-4.5;0.75': ['sim_11', 'sim_51'],
#  '-0.3;-0.5;-5.0;-5.0;0.25': ['sim_4', 'sim_39'],
#  '-0.3;-0.5;-5.0;-5.0;0.75': ['sim_2', 'sim_37'],
#  '-0.5;-0.3;-4.5;-4.5;0.25': ['sim_28', 'sim_60'],
#  '-0.5;-0.3;-4.5;-4.5;0.75': ['sim_25', 'sim_45'],
#  '-0.5;-0.3;-4.5;-5.0;0.25': ['sim_30', 'sim_44'],
#  '-0.5;-0.3;-4.5;-5.0;0.75': ['sim_3', 'sim_54'],
#  '-0.5;-0.3;-5.0;-4.5;0.25': ['sim_5', 'sim_52'],
#  '-0.5;-0.3;-5.0;-4.5;0.75': ['sim_15', 'sim_57'],
#  '-0.5;-0.3;-5.0;-5.0;0.25': ['sim_18', 'sim_41'],
#  '-0.5;-0.3;-5.0;-5.0;0.75': ['sim_17', 'sim_46'],
#  '-0.5;-0.5;-4.5;-4.5;0.25': ['sim_20', 'sim_50'],
#  '-0.5;-0.5;-4.5;-4.5;0.75': ['sim_19', 'sim_42'],
#  '-0.5;-0.5;-4.5;-5.0;0.25': ['sim_27', 'sim_56'],
#  '-0.5;-0.5;-4.5;-5.0;0.75': ['sim_23', 'sim_59'],
#  '-0.5;-0.5;-5.0;-4.5;0.25': ['sim_22', 'sim_49'],
#  '-0.5;-0.5;-5.0;-4.5;0.75': ['sim_31', 'sim_64'],
#  '-0.5;-0.5;-5.0;-5.0;0.25': ['sim_29', 'sim_61'],
#  '-0.5;-0.5;-5.0;-5.0;0.75': ['sim_32', 'sim_62']}

# %% [markdown]
# ### Load Field Parameters

# %%
field_params = get_field_parameters(sim_names, sim_paths)
print("Field Parameters: \n")
pprint(field_params)
# Out:
# Field Parameters:
#
# {'sim_1': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_10': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_11': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_12': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_13': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_14': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_15': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_16': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_17': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_18': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_19': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_2': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_20': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_21': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_22': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_23': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_24': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_25': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_26': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_27': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_28': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_29': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_3': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_30': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_31': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_32': {'Chr_CG': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 364.932,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 27,
#             'ny': 27,
#             'nz': 27,
#             'vf_limit': 0.5,
#             'x_width': 771.429,
#             'y_width': 771.429,
#             'z_width': 771.429},
#  'sim_33': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_34': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_35': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_36': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_37': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_38': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_39': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_4': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_40': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_41': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_42': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_43': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_44': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_45': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_46': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_47': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_48': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_49': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_5': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_50': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_51': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_52': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_53': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_54': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_55': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_56': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_57': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_58': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_59': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_6': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_60': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_61': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_62': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_63': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_64': {'Chr_refine': 'polymer',
#             'HP1': 'binder',
#             'PRC1': 'binder',
#             'assume_fully_accessible': 'True',
#             'chi': 1,
#             'confine_length': 899.993,
#             'confine_type': 'Spherical',
#             'fast_field': 'True',
#             'nx': 68,
#             'ny': 68,
#             'nz': 68,
#             'vf_limit': 0.5,
#             'x_width': 1942.857,
#             'y_width': 1942.857,
#             'z_width': 1942.857},
#  'sim_7': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_8': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429},
#  'sim_9': {'Chr_CG': 'polymer',
#            'HP1': 'binder',
#            'PRC1': 'binder',
#            'assume_fully_accessible': 'True',
#            'chi': 1,
#            'confine_length': 364.932,
#            'confine_type': 'Spherical',
#            'fast_field': 'True',
#            'nx': 27,
#            'ny': 27,
#            'nz': 27,
#            'vf_limit': 0.5,
#            'x_width': 771.429,
#            'y_width': 771.429,
#            'z_width': 771.429}}

# %% [markdown]
# ### Create JSON Output of Simulation Parameters

# %%
params_json = create_parameter_json(sim_names, binder_params, field_params)
print("All Parameters: \n")
print(params_json)
# Out:
# All Parameters:
#
# {
#     "sim_1": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_2": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_3": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_4": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_5": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_6": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_7": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_8": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_9": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_10": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_11": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_12": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_13": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_14": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_15": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_16": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_17": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_18": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_19": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_20": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_21": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_22": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_23": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_24": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_25": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 771.429,
#             "nx": 27,
#             "y_width": 771.429,
#             "ny": 27,
#             "z_width": 771.429,
#             "nz": 27,
#             "confine_type": "Spherical",
#             "confine_length": 364.932,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_CG": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_26": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
# ...
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_57": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_58": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_59": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_60": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_61": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 659459.682
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.25}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_62": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_63": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.3,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     },
#     "sim_64": {
#         "binder_parameters": {
#             "HP1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -5.0,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 1978379.047
#                 },
#                 "cross_talk_interaction_energy": "{'PRC1': 0.75}",
#                 "field_energy_prefactor": -6594596.824,
#                 "interaction_energy_intranucleosome": -4.976,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             },
#             "PRC1": {
#                 "sites_per_bead": 2,
#                 "interaction_energy": -4.5,
#                 "chemical_potential": -0.5,
#                 "bind_energy_mod": -0.01,
#                 "bind_energy_no_mod": 1.52,
#                 "cross_talk_field_energy_prefactor": {
#                     "HP1": 0.0,
#                     "PRC1": 0.0
#                 },
#                 "cross_talk_interaction_energy": "{}",
#                 "field_energy_prefactor": -5935137.141,
#                 "interaction_energy_intranucleosome": -4.478,
#                 "interaction_radius": 3.0,
#                 "interaction_volume": 113.097
#             }
#         },
#         "field_parameters": {
#             "x_width": 1942.857,
#             "nx": 68,
#             "y_width": 1942.857,
#             "ny": 68,
#             "z_width": 1942.857,
#             "nz": 68,
#             "confine_type": "Spherical",
#             "confine_length": 899.993,
#             "chi": 1,
#             "assume_fully_accessible": "True",
#             "vf_limit": 0.5,
#             "fast_field": "True",
#             "Chr_refine": "polymer",
#             "HP1": "binder",
#             "PRC1": "binder"
#         }
#     }
# }
